# %%
import nibabel as nib

# %%
epi_img = nib.load('/Users/andymetcalf/Documents/DeepLearning/project/code/prediction/validation_case_56/prediction.nii.gz')
epi_img_data = epi_img.get_data()
epi_img_data.shape
# Out:
# (128, 128, 128)

# %%
epi_img = nib.load('/Users/andymetcalf/Documents/DeepLearning/project/code/data/original/HGG/Brats17_2013_10_1/Brats17_2013_10_1_flair.nii.gz')
epi_img_data = epi_img.get_data()
epi_img_data.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ee1374bfe671> in <module>()
# ----> 1 epi_img = nib.load('/Users/andymetcalf/Documents/DeepLearning/project/code/data/original/HGG/Brats17_2013_10_1/Brats17_2013_10_1_flair.nii.gz')
#       2 epi_img_data = epi_img.get_data()
#       3 epi_img_data.shape
#
# /Applications/anaconda/envs/3.6/lib/python3.6/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      38     '''
#      39     if not op.exists(filename):
# ---> 40         raise FileNotFoundError("No such file: '%s'" % filename)
#      41     sniff = None
#      42     for image_klass in all_image_classes:
#
# FileNotFoundError: No such file: '/Users/andymetcalf/Documents/DeepLearning/project/code/data/original/HGG/Brats17_2013_10_1/Brats17_2013_10_1_flair.nii.gz'

# %%
import matplotlib.pyplot as plt



slice_0 = epi_img_data[:, :, 20]
slice_1 = epi_img_data[:, :, 59]
slice_2 = epi_img_data[:, :, 60]

slices = [slice_0, slice_1, slice_2]

fs = 100

fig, axs = plt.subplots(1, len(slices), figsize=(fs,fs))
for i, slice in enumerate(slices):
    axs[i].imshow(slice.T, cmap="gray", origin="lower")
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt



slice_0 = epi_img_data[:, :, 20]
slice_1 = epi_img_data[:, :, 59]
slice_2 = epi_img_data[:, :, 60]

slices = [slice_0, slice_1, slice_2]

fs = 100

fig, axs = plt.subplots(1, len(slices), figsize=(fs,fs))
for i, slice in enumerate(slices):
    axs[i].imshow(slice.T, cmap="gray", origin="lower")
plt.show()
plt.close()

# %%
import PIL as pl

# %%
from PIL import Image, ImageSequence
filename = sys.argv[1]
im = Image.open(filename)
original_duration = im.info['duration']
frames = [frame.copy() for frame in ImageSequence.Iterator(im)]    
frames.reverse()

from images2gif import writeGif
writeGif("reverse_" + os.path.basename(filename), frames, duration=original_duration/1000.0, dither=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e637583c1eec> in <module>()
#       1 from PIL import Image, ImageSequence
# ----> 2 filename = sys.argv[1]
#       3 im = Image.open(filename)
#       4 original_duration = im.info['duration']
#       5 frames = [frame.copy() for frame in ImageSequence.Iterator(im)]
#
# NameError: name 'sys' is not defined
